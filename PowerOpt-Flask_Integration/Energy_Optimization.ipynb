# %% [markdown]
# <a href="https://colab.research.google.com/github/Amruthavalli-k/PowerOpt/blob/main/Energy_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Loading the dataset**

# %%
df = pd.read_csv('/content/Steel_industry_dataset.csv')
df.head()
# Out:
#                date  Usage_kWh  Lagging_Current_Reactive_Power_kVarh  \
# 0  01-01-2018 00:15       3.17                                  2.95
# 1  01-01-2018 00:30       4.00                                  4.46
# 2  01-01-2018 00:45       3.24                                  3.28
# 3  01-01-2018 01:00       3.31                                  3.56
# 4  01-01-2018 01:15       3.82                                  4.50
#
#    Leading_Current_Reactive_Power_kVarh  CO2  Lagging_Current_Power_Factor  \
# 0                                   0.0  0.0                         73.21
# 1                                   0.0  0.0                         66.77
# 2                                   0.0  0.0                         70.28
# 3                                   0.0  0.0                         68.09
# 4                                   0.0  0.0                         64.72
#
#    Leading_Current_Power_Factor     NSM WeekStatus Day_of_week   Load_Type
# 0                         100.0   900.0    Weekday      Monday  Light_Load
# 1                         100.0  1800.0    Weekday      Monday  Light_Load
# 2                         100.0  2700.0    Weekday      Monday  Light_Load
# 3                         100.0  3600.0    Weekday      Monday  Light_Load
# 4                         100.0  4500.0    Weekday      Monday  Light_Load

# %% [markdown]
# ### **Dataset Columns:**
#
# **date:** Timestamp of the data record (e.g., "01/01/2018 00:15").
#
# **Usage_kWh:** Energy consumption in kilowatt-hours.
#
# **Lagging_Current_Reactive.Power_kVarh:** Reactive power with a lagging current in kilovolt-ampere reactive hours.
#
# **Leading_Current_Reactive.Power_kVarh:** Reactive power with a leading current in kilovolt-ampere reactive hours.
#
# **CO2:** Carbon dioxide emissions in metric tons.
#
# **Lagging_Current_Power_Factor**: Power factor for lagging current.
#
# **Leading_Current_Power_Factor:** Power factor for leading current.
#
# **NSM:** Numeric time indicator (possibly in seconds).
#
# **WeekStatus:** Whether the day is a "Weekday" or "Weekend".
#
# **Day_of_week:** Day of the week (e.g., "Monday").
#
# **Load_Type:** Type of load (e.g., "Light_Load").

# %%
#Summary of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13419 entries, 0 to 13418
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   date                                  13419 non-null  object
#  1   Usage_kWh                             13419 non-null  float64
#  2   Lagging_Current_Reactive_Power_kVarh  13418 non-null  float64
#  3   Leading_Current_Reactive_Power_kVarh  13418 non-null  float64
#  4   CO2                                   13418 non-null  float64
#  5   Lagging_Current_Power_Factor          13418 non-null  float64
#  6   Leading_Current_Power_Factor          13418 non-null  float64
#  7   NSM                                   13418 non-null  float64
#  8   WeekStatus                            13418 non-null  object
#  9   Day_of_week                           13418 non-null  object
#  10  Load_Type                             13418 non-null  object
# dtypes: float64(7), object(4)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (13419, 11)

# %%
df.columns
# Out:
# Index(['date', 'Usage_kWh', 'Lagging_Current_Reactive_Power_kVarh',
#        'Leading_Current_Reactive_Power_kVarh', 'CO2',
#        'Lagging_Current_Power_Factor', 'Leading_Current_Power_Factor', 'NSM',
#        'WeekStatus', 'Day_of_week', 'Load_Type'],
#       dtype='object')

# %%
# Descriptive Statistics
df.describe().T
# Out:
#                                         count          mean           std  \
# Usage_kWh                             13419.0     31.798940     36.480498
# Lagging_Current_Reactive_Power_kVarh  13418.0     13.570573     16.822910
# Leading_Current_Reactive_Power_kVarh  13418.0      4.246339      8.293519
# CO2                                   13418.0      0.013510      0.017584
# Lagging_Current_Power_Factor          13418.0     83.756157     15.373554
# Leading_Current_Power_Factor          13418.0     85.479456     29.952465
# NSM                                   13418.0  42700.365181  24922.094263
#
#                                         min         25%        50%       75%  \
# Usage_kWh                              2.56      3.6400      5.870     57.78
# Lagging_Current_Reactive_Power_kVarh   0.00      2.7400      4.640     24.41
# Leading_Current_Reactive_Power_kVarh   0.00      0.0000      0.000      1.84
# CO2                                    0.00      0.0000      0.000      0.03
# Lagging_Current_Power_Factor          46.23     69.6025     89.735     99.22
# Leading_Current_Power_Factor          12.50     99.8900    100.000    100.00
# NSM                                    0.00  20700.0000  42300.000  63900.00
#
#                                            max
# Usage_kWh                               153.14
# Lagging_Current_Reactive_Power_kVarh     96.91
# Leading_Current_Reactive_Power_kVarh     27.76
# CO2                                       0.07
# Lagging_Current_Power_Factor            100.00
# Leading_Current_Power_Factor            100.00
# NSM                                   85500.00

# %% [markdown]
# ## **Data Preprocessing**

# %% [markdown]
# ### **Handling Missing Values**

# %%
  df.isna().sum()
# Out:
# date                                    0
# Usage_kWh                               0
# Lagging_Current_Reactive_Power_kVarh    1
# Leading_Current_Reactive_Power_kVarh    1
# CO2                                     1
# Lagging_Current_Power_Factor            1
# Leading_Current_Power_Factor            1
# NSM                                     1
# WeekStatus                              1
# Day_of_week                             1
# Load_Type                               1
# dtype: int64

# %%
#Removing Null values
df.dropna(inplace =True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13418 entries, 0 to 13417
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   date                                  13418 non-null  object
#  1   Usage_kWh                             13418 non-null  float64
#  2   Lagging_Current_Reactive_Power_kVarh  13418 non-null  float64
#  3   Leading_Current_Reactive_Power_kVarh  13418 non-null  float64
#  4   CO2                                   13418 non-null  float64
#  5   Lagging_Current_Power_Factor          13418 non-null  float64
#  6   Leading_Current_Power_Factor          13418 non-null  float64
#  7   NSM                                   13418 non-null  float64
#  8   WeekStatus                            13418 non-null  object
#  9   Day_of_week                           13418 non-null  object
#  10  Load_Type                             13418 non-null  object
# dtypes: float64(7), object(4)
# memory usage: 1.2+ MB

# %%
#Analysing Unique Values of each column
for column in df.columns:
    print(f"Unique values in column '{column}': {df[column].unique()}")
# Out:
# Unique values in column 'date': ['01-01-2018 00:15' '01-01-2018 00:30' '01-01-2018 00:45' ...
#  '20-05-2018 18:00' '20-05-2018 18:15' '20-05-2018 18:30']
# Unique values in column 'Usage_kWh': [ 3.17  4.    3.24 ... 11.45 13.82 11.02]
# Unique values in column 'Lagging_Current_Reactive_Power_kVarh': [ 2.95  4.46  3.28 ... 83.59 52.78 39.74]
#  21.74 16.09 12.06 11.88 11.95 11.52 11.45]
# Unique values in column 'CO2': [0.   0.02 0.03 0.05 0.06 0.04 0.01 0.07]
# Unique values in column 'Lagging_Current_Power_Factor': [73.21 66.77 70.28 ... 46.37 50.54 68.23]
# Unique values in column 'Leading_Current_Power_Factor': [100.    99.87  24.11 ...  23.94  63.23  73.04]
# Unique values in column 'NSM': [  900.  1800.  2700.  3600.  4500.  5400.  6300.  7200.  8100.  9000.
#   9900. 10800. 11700. 12600. 13500. 14400. 15300. 16200. 17100. 18000.
#  18900. 19800. 20700. 21600. 22500. 23400. 24300. 25200. 26100. 27000.
#  27900. 28800. 29700. 30600. 31500. 32400. 33300. 34200. 35100. 36000.
#  36900. 37800. 38700. 39600. 40500. 41400. 42300. 43200. 44100. 45000.
#  45900. 46800. 47700. 48600. 49500. 50400. 51300. 52200. 53100. 54000.
#  54900. 55800. 56700. 57600. 58500. 59400. 60300. 61200. 62100. 63000.
#  63900. 64800. 65700. 66600. 67500. 68400. 69300. 70200. 71100. 72000.
#  72900. 73800. 74700. 75600. 76500. 77400. 78300. 79200. 80100. 81000.
#  81900. 82800. 83700. 84600. 85500.     0.]
# Unique values in column 'WeekStatus': ['Weekday' 'Weekend']
# Unique values in column 'Day_of_week': ['Monday' 'Tuesday' 'Wednesday' 'Thursday' 'Friday' 'Saturday' 'Sunday']
# Unique values in column 'Load_Type': ['Light_Load' 'Medium_Load' 'Maximum_Load']

# %% [markdown]
# ## **Exploratory Data Analysis(EDA)**

# %% [markdown]
# ### **Univariate Analysis**

# %%
numerical_cols = ['Usage_kWh', 'Lagging_Current_Reactive_Power_kVarh',
                  'Leading_Current_Reactive_Power_kVarh', 'CO2',
                  'Lagging_Current_Power_Factor', 'Leading_Current_Power_Factor']

# Histograms
df[numerical_cols].hist(bins=20, figsize=(12, 10))
plt.suptitle('Histograms of Numerical Features')
plt.show()

# %% [markdown]
# line plot to target var and bin
# flat-do not consider

# %%
# Boxplot for outliers detection
plt.figure(figsize=(12, 10))
sns.boxplot(data=df[numerical_cols])
plt.title('Boxplots of Numerical Features')
plt.xticks(rotation=45)
plt.show()

# %%
# Frequency count of categorical variable Load_Type
print(df['Load_Type'].value_counts())

# Visualizing Load_Type distribution
sns.countplot(x='Load_Type', data=df)
plt.title('Distribution of Load Type')
plt.show()
# Out:
# Load_Type
# Light_Load      6884
# Medium_Load     3726
# Maximum_Load    2808
# Name: count, dtype: int64

# %%
categorical_columns = ['WeekStatus', 'Day_of_week', 'Load_Type']

for col in categorical_columns:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=df, x=col, palette='Set2')
    plt.title(f'Count of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()
# Out:
# <ipython-input-14-3df65ce7d86c>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')
# <ipython-input-14-3df65ce7d86c>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')
# <ipython-input-14-3df65ce7d86c>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')

# %% [markdown]
# ## **Bivariate Analysis**

# %%
# Bivariate Analysis: Numerical vs. Numerical
for i in range(len(numerical_cols)):
    for j in range(i + 1, len(numerical_cols)):
        x = numerical_cols[i]
        y = numerical_cols[j]
        plt.figure(figsize=(8, 6))
        sns.scatterplot(data=df, x=x, y=y)
        plt.title(f'Scatter Plot: {x} vs {y}')
        plt.show()

# %% [markdown]
# ### **Multivariate Analysis**

# %%
# Correlation matrix for numerical features
corr_matrix = df[numerical_cols].corr()
print(corr_matrix)
# Out:
#                                       Usage_kWh  \
# Usage_kWh                              1.000000
# Lagging_Current_Reactive_Power_kVarh   0.879987
# Leading_Current_Reactive_Power_kVarh  -0.336436
# CO2                                    0.983139
# Lagging_Current_Power_Factor           0.407588
# Leading_Current_Power_Factor           0.357291
#
#                                       Lagging_Current_Reactive_Power_kVarh  \
# Usage_kWh                                                         0.879987
# Lagging_Current_Reactive_Power_kVarh                              1.000000
# Leading_Current_Reactive_Power_kVarh                             -0.400256
# CO2                                                               0.864088
# Lagging_Current_Power_Factor                                      0.138458
# Leading_Current_Power_Factor                                      0.387151
#
#                                       Leading_Current_Reactive_Power_kVarh  \
# Usage_kWh                                                        -0.336436
# Lagging_Current_Reactive_Power_kVarh                             -0.400256
# Leading_Current_Reactive_Power_kVarh                              1.000000
# CO2                                                              -0.341915
# Lagging_Current_Power_Factor                                      0.529312
# Leading_Current_Power_Factor                                     -0.950808
#
#                                            CO2  Lagging_Current_Power_Factor  \
# Usage_kWh                             0.983139                      0.407588
# Lagging_Current_Reactive_Power_kVarh  0.864088                      0.138458
# Leading_Current_Reactive_Power_kVarh -0.341915                      0.529312
# CO2                                   1.000000                      0.404111
# Lagging_Current_Power_Factor          0.404111                      1.000000
# Leading_Current_Power_Factor          0.363129                     -0.501232
#
#                                       Leading_Current_Power_Factor
# Usage_kWh                                                 0.357291
# Lagging_Current_Reactive_Power_kVarh                      0.387151
# Leading_Current_Reactive_Power_kVarh                     -0.950808
# CO2                                                       0.363129
# Lagging_Current_Power_Factor                             -0.501232
# Leading_Current_Power_Factor                              1.000000

# %%
# Heatmap visualization
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
#Pair Plot
sns.pairplot(df[numerical_cols])
plt.suptitle('Pairplot of Numerical Features', size=16)
plt.show()

# %% [markdown]
# ## **Handling Outliers**

# %%
from scipy.stats import zscore

# %%
z_scores = df[numerical_cols].apply(zscore)

# Identify outliers
outliers_zscore = {}
threshold = 3
for col in numerical_cols:
    outliers_zscore[col] = df[(z_scores[col] > threshold) | (z_scores[col] < -threshold)]

# Print outliers for each column
for col, outlier_data in outliers_zscore.items():
    print(f"Outliers in {col}:\n", outlier_data)
# Out:
# Outliers in Usage_kWh:
#                    date  Usage_kWh  Lagging_Current_Reactive_Power_kVarh  \
# 141   02-01-2018 11:30     144.47                                 78.48
# 1710                         92.08                         100.0  71100.0
# 2474                         93.62                         100.0  67500.0
# 2757                         93.07                         100.0  63000.0
# 2768                         92.43                         100.0  72900.0
# 2937                         93.06                         100.0  52200.0
# 3023                         87.13                         100.0  43200.0
# 6111                         90.16                         100.0  57600.0
# 7812                         91.84                         100.0  33300.0
# 7835                         90.45                         100.0  54000.0
#
#      WeekStatus Day_of_week     Load_Type
# 141     Weekday     Tuesday  Maximum_Load
# 155     Weekday     Tuesday   Medium_Load
# 157     Weekday     Tuesday   Medium_Load
# 162     Weekday     Tuesday   Medium_Load
# 352     Weekday    Thursday   Medium_Load
# 447     Weekday      Friday   Medium_Load
# 452     Weekday      Friday  Maximum_Load
# 749     Weekday      Monday  Maximum_Load
# 751     Weekday      Monday  Maximum_Load
# 908     Weekday   Wednesday  Maximum_Load
# 1093    Weekday      Friday   Medium_Load
# 1397    Weekday      Monday   Medium_Load
# 1398    Weekday      Monday   Medium_Load
# 1676    Weekday    Thursday  Maximum_Load
# 1678    Weekday    Thursday  Maximum_Load
# 1679    Weekday    Thursday  Maximum_Load
# 1697    Weekday    Thursday   Medium_Load
# 1701    Weekday    Thursday  Maximum_Load
# 1710    Weekday    Thursday  Maximum_Load
# 2474    Weekday      Friday  Maximum_Load
# 2757    Weekday      Monday  Maximum_Load
# 2768    Weekday      Monday   Medium_Load
# 2937    Weekday   Wednesday   Medium_Load
# 3023    Weekday    Thursday  Maximum_Load
# 6111    Weekday      Monday  Maximum_Load
# 7812    Weekday      Friday   Medium_Load
# 7835    Weekday      Friday  Maximum_Load
# Outliers in Lagging_Current_Reactive_Power_kVarh:
#                     date  Usage_kWh  Lagging_Current_Reactive_Power_kVarh  \
# 140    02-01-2018 11:15     128.52                                 70.85
# 141    02-01-2018 11:30     144.47                                 78.48
# 143    02-01-2018 12:00     123.30                                 66.06
# 162    02-01-2018 16:45     147.46                                 65.27
# 321    04-01-2018 08:30     136.19                                 74.88
# ...                 ...        ...                                   ...
# 13102  17-05-2018 11:45     125.68                                 80.75
# 13110  17-05-2018 13:45     133.78                                 67.21
# 13129  17-05-2018 18:30     112.28                                 64.04
# 13185  18-05-2018 08:30     100.94                                 71.42
# 13186  18-05-2018 08:45     120.49                                 83.59
#
#        Leading_Current_Reactive_Power_kVarh   CO2  \
# 140                                     0.0  0.00
# 141                                     0.0  0.00
# 143                                     0.0  0.00
# 162                                     0.0  0.00
# 321                                     0.0  0.06
# ...                                     ...   ...
# 13102                                   0.0  0.06
# 13110                                   0.0  0.06
# 13129                                   0.0  0.05
# 13185                                   0.0  0.05
# 13186                                   0.0  0.06
#
#        Lagging_Current_Power_Factor  Leading_Current_Power_Factor      NSM  \
# 140                           87.57                         100.0  40500.0
# 141                           87.87                         100.0  41400.0
# 143                           88.15                         100.0  43200.0
# 162                           91.44                         100.0  60300.0
# 321                           87.63                         100.0  30600.0
# ...                             ...                           ...      ...
# 13102                         84.13                         100.0  42300.0
# 13110                         89.36                         100.0  49500.0
# 13129                         86.86                         100.0  66600.0
# 13185                         81.63                         100.0  30600.0
# 13186                         82.16                         100.0  31500.0
#
#       WeekStatus Day_of_week     Load_Type
# 140      Weekday     Tuesday  Maximum_Load
# 141      Weekday     Tuesday  Maximum_Load
# 143      Weekday     Tuesday  Maximum_Load
# 162      Weekday     Tuesday   Medium_Load
# 321      Weekday    Thursday    Light_Load
# ...          ...         ...           ...
# 13102    Weekday    Thursday  Maximum_Load
# 13110    Weekday    Thursday  Maximum_Load
# 13129    Weekday    Thursday   Medium_Load
# 13185    Weekday      Friday    Light_Load
# 13186    Weekday      Friday    Light_Load
#
# [137 rows x 11 columns]
# Outliers in Leading_Current_Reactive_Power_kVarh:
#  Empty DataFrame
# Columns: [date, Usage_kWh, Lagging_Current_Reactive_Power_kVarh, Leading_Current_Reactive_Power_kVarh, CO2, Lagging_Current_Power_Factor, Leading_Current_Power_Factor, NSM, WeekStatus, Day_of_week, Load_Type]
# Index: []
# Outliers in CO2:
#                    date  Usage_kWh  Lagging_Current_Reactive_Power_kVarh  \
# 352   04-01-2018 16:15     144.29                                 54.94
# 447   05-01-2018 16:00     146.34                                 66.92
# 452   05-01-2018 17:15     145.69                                 66.35
# 749   08-01-2018 19:30     143.78                                 64.30
# 751   08-01-2018 20:00     145.30                                 61.74
# 908   10-01-2018 11:15     143.21                                 70.56
# 1093  12-01-2018 09:30     143.17                                 63.65
# 1397  15-01-2018 13:30     146.27                                 76.79
# 1398  15-01-2018 13:45     153.14                                 70.45
# 1676  18-01-2018 11:15     143.93                                 72.18
# 1678  18-01-2018 11:45     142.85                                 75.17
# 1679  18-01-2018 12:00     146.48                                 84.89
# 1697  18-01-2018 16:30     142.56                                 64.22
# 1701  18-01-2018 17:30     149.65                                 64.87
# 2474  26-01-2018 18:45     144.07                                 54.11
# 2757  29-01-2018 17:30     142.67                                 56.09
# 2768  29-01-2018 20:15     142.70                                 58.93
# 2937  31-01-2018 14:30     143.82                                 56.56
# 3023  01-02-2018 12:00     145.51                                 81.94
# 6111  05-03-2018 16:00     146.88                                 70.49
# 7812  23-03-2018 09:15     151.31                                 65.20
# 7835  23-03-2018 15:00     142.78                                 67.32
#
#       Leading_Current_Reactive_Power_kVarh   CO2  \
# 352                                    0.0  0.07
# 447                                    0.0  0.07
# 452                                    0.0  0.07
# 749                                    0.0  0.07
# 751                                    0.0  0.07
# 908                                    0.0  0.07
# 1093                                   0.0  0.07
# 1397                                   0.0  0.07
# 1398                                   0.0  0.07
# 1676                                   0.0  0.07
# 1678                                   0.0  0.07
# 1679                                   0.0  0.07
# 1697                                   0.0  0.07
# 1701                                   0.0  0.07
# 2474                                   0.0  0.07
# 2757                                   0.0  0.07
# 2768                                   0.0  0.07
# 2937                                   0.0  0.07
# 3023                                   0.0  0.07
# 6111                                   0.0  0.07
# 7812                                   0.0  0.07
# 7835                                   0.0  0.07
#
#       Lagging_Current_Power_Factor  Leading_Current_Power_Factor      NSM  \
# 352                          93.45                         100.0  58500.0
# 447                          90.94                         100.0  57600.0
# 452                          91.01                         100.0  62100.0
# 749                          91.29                         100.0  70200.0
# 751                          92.04                         100.0  72000.0
# 908                          89.70                         100.0  40500.0
# 1093                         91.38                         100.0  34200.0
# 1397                         88.54                         100.0  48600.0
# 1398                         90.85                         100.0  49500.0
# 1676                         89.39                         100.0  40500.0
# 1678                         88.50                         100.0  42300.0
# 1679                         86.52                         100.0  43200.0
# 1697                         91.18                         100.0  59400.0
# 1701                         91.75                         100.0  63000.0
# 2474                         93.62                         100.0  67500.0
# 2757                         93.07                         100.0  63000.0
# 2768                         92.43                         100.0  72900.0
# 2937                         93.06                         100.0  52200.0
# 3023                         87.13                         100.0  43200.0
# 6111                         90.16                         100.0  57600.0
# 7812                         91.84                         100.0  33300.0
# 7835                         90.45                         100.0  54000.0
#
#      WeekStatus Day_of_week     Load_Type
# 352     Weekday    Thursday   Medium_Load
# 447     Weekday      Friday   Medium_Load
# 452     Weekday      Friday  Maximum_Load
# 749     Weekday      Monday  Maximum_Load
# 751     Weekday      Monday  Maximum_Load
# 908     Weekday   Wednesday  Maximum_Load
# 1093    Weekday      Friday   Medium_Load
# 1397    Weekday      Monday   Medium_Load
# 1398    Weekday      Monday   Medium_Load
# 1676    Weekday    Thursday  Maximum_Load
# 1678    Weekday    Thursday  Maximum_Load
# 1679    Weekday    Thursday  Maximum_Load
# 1697    Weekday    Thursday   Medium_Load
# 1701    Weekday    Thursday  Maximum_Load
# 2474    Weekday      Friday  Maximum_Load
# 2757    Weekday      Monday  Maximum_Load
# 2768    Weekday      Monday   Medium_Load
# 2937    Weekday   Wednesday   Medium_Load
# 3023    Weekday    Thursday  Maximum_Load
# 6111    Weekday      Monday  Maximum_Load
# 7812    Weekday      Friday   Medium_Load
# 7835    Weekday      Friday  Maximum_Load
# Outliers in Lagging_Current_Power_Factor:
#  Empty DataFrame
# Columns: [date, Usage_kWh, Lagging_Current_Reactive_Power_kVarh, Leading_Current_Reactive_Power_kVarh, CO2, Lagging_Current_Power_Factor, Leading_Current_Power_Factor, NSM, WeekStatus, Day_of_week, Load_Type]
# Index: []
# Outliers in Leading_Current_Power_Factor:
#  Empty DataFrame
# Columns: [date, Usage_kWh, Lagging_Current_Reactive_Power_kVarh, Leading_Current_Reactive_Power_kVarh, CO2, Lagging_Current_Power_Factor, Leading_Current_Power_Factor, NSM, WeekStatus, Day_of_week, Load_Type]
# Index: []

# %% [markdown]
# ## **Binning**

# %%
# Define bins and labels for binning
bins = [0,15, 35, 85, 100]
labels = [1,5,2,10]

# Apply binning to the 'Leading_Current_Power_Factor' column
df['Power_Factor_Bin'] = pd.cut(df['Leading_Current_Power_Factor'], bins=bins, labels=labels, include_lowest=True)

print(df[['Leading_Current_Power_Factor', 'Power_Factor_Bin']].head(50))
# Out:
#     Leading_Current_Power_Factor Power_Factor_Bin
# 0                         100.00               10
# 1                         100.00               10
# 2                         100.00               10
# 3                         100.00               10
# 4                         100.00               10
# 5                         100.00               10
# 6                         100.00               10
# 7                         100.00               10
# 8                         100.00               10
# 9                         100.00               10
# 10                        100.00               10
# 11                        100.00               10
# 12                        100.00               10
# 13                        100.00               10
# 14                        100.00               10
# 15                        100.00               10
# 16                        100.00               10
# 17                        100.00               10
# 18                        100.00               10
# 19                        100.00               10
# 20                        100.00               10
# 21                        100.00               10
# 22                        100.00               10
# 23                        100.00               10
# 24                        100.00               10
# 25                        100.00               10
# 26                        100.00               10
# 27                        100.00               10
# 28                        100.00               10
# 29                        100.00               10
# 30                        100.00               10
# 31                        100.00               10
# 32                        100.00               10
# 33                        100.00               10
# 34                         99.87               10
# 35                         24.11                5
# 36                         20.76                5
# 37                         18.61                5
# 38                         19.98                5
# 39                         21.08                5
# 40                         17.94                5
# 41                         20.19                5
# 42                         20.81                5
# 43                         17.71                5
# 44                         52.55                2
# 45                         58.31                2
# 46                         51.26                2
# 47                         60.69                2
# 48                         26.90                5
# 49                         18.06                5

# %%
df['Power_Factor_Bin'].isna().sum()
# Out:
# 0

# %%
x=df['Usage_kWh']
plt.plot(x,df['Power_Factor_Bin'])

# %% [markdown]
# ## **Encoding**

# %%
# Drop the 'Day_of_week' column from the dataset
df = df.drop(columns=['Day_of_week'])

print(df.head())
# Out:
#                date  Usage_kWh  Lagging_Current_Reactive_Power_kVarh  \
# 0  01-01-2018 00:15       3.17                                  2.95
# 1  01-01-2018 00:30       4.00                                  4.46
# 2  01-01-2018 00:45       3.24                                  3.28
# 3  01-01-2018 01:00       3.31                                  3.56
# 4  01-01-2018 01:15       3.82                                  4.50
#
#    Leading_Current_Reactive_Power_kVarh  CO2  Lagging_Current_Power_Factor  \
# 0                                   0.0  0.0                         73.21
# 1                                   0.0  0.0                         66.77
# 2                                   0.0  0.0                         70.28
# 3                                   0.0  0.0                         68.09
# 4                                   0.0  0.0                         64.72
#
#    Leading_Current_Power_Factor     NSM WeekStatus   Load_Type  \
# 0                         100.0   900.0    Weekday  Light_Load
# 1                         100.0  1800.0    Weekday  Light_Load
# 2                         100.0  2700.0    Weekday  Light_Load
# 3                         100.0  3600.0    Weekday  Light_Load
# 4                         100.0  4500.0    Weekday  Light_Load
#
#   Power_Factor_Bin
# 0               10
# 1               10
# 2               10
# 3               10
# 4               10

# %%
from sklearn.preprocessing import LabelEncoder

# One-hot encoding for 'WeekStatus' column
df = pd.get_dummies(df, columns=['WeekStatus'], prefix='WeekStatus')

# Label encoding for 'Load_Type' column
label_encoder = LabelEncoder()
df['Load_Type_Encoded'] = label_encoder.fit_transform(df['Load_Type'])

# %%
df
# Out:
#                    date  Usage_kWh  Lagging_Current_Reactive_Power_kVarh  \
# 0      01-01-2018 00:15       3.17                                  2.95
# 1      01-01-2018 00:30       4.00                                  4.46
# 2      01-01-2018 00:45       3.24                                  3.28
# 3      01-01-2018 01:00       3.31                                  3.56
# 4      01-01-2018 01:15       3.82                                  4.50
# ...                 ...        ...                                   ...
# 13413  20-05-2018 17:30       4.03                                  0.00
# 13414  20-05-2018 17:45       4.10                                  0.00
# 13415  20-05-2018 18:00       3.96                                  0.00
# 13416  20-05-2018 18:15       3.82                                  0.00
# 13417  20-05-2018 18:30       3.85                                  0.00
#
#        Leading_Current_Reactive_Power_kVarh  CO2  \
# 0                                      0.00  0.0
# 1                                      0.00  0.0
# 2                                      0.00  0.0
# 3                                      0.00  0.0
# 4                                      0.00  0.0
# ...                                     ...  ...
# 13413                                 15.95  0.0
# 13414                                 15.95  0.0
# 13415                                 16.06  0.0
# 13416                                  4.68  0.0
# 13417                                  3.60  0.0
#
#        Lagging_Current_Power_Factor  Leading_Current_Power_Factor      NSM  \
# 0                             73.21                        100.00    900.0
# 1                             66.77                        100.00   1800.0
# 2                             70.28                        100.00   2700.0
# 3                             68.09                        100.00   3600.0
# 4                             64.72                        100.00   4500.0
# ...                             ...                           ...      ...
# 13413                        100.00                         24.50  63000.0
# 13414                        100.00                         24.90  63900.0
# 13415                        100.00                         23.94  64800.0
# 13416                        100.00                         63.23  65700.0
# 13417                        100.00                         73.04  66600.0
#
#          Load_Type Power_Factor_Bin  WeekStatus_Weekday  WeekStatus_Weekend  \
# 0       Light_Load               10                True               False
# 1       Light_Load               10                True               False
# 2       Light_Load               10                True               False
# 3       Light_Load               10                True               False
# 4       Light_Load               10                True               False
# ...            ...              ...                 ...                 ...
# 13413  Medium_Load                5               False                True
# 13414  Medium_Load                5               False                True
# 13415  Medium_Load                5               False                True
# 13416  Medium_Load                2               False                True
# 13417  Medium_Load                2               False                True
#
#        Load_Type_Encoded
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 13413                  2
# 13414                  2
# 13415                  2
# 13416                  2
# 13417                  2
#
# [13418 rows x 13 columns]

# %% [markdown]
# ## **Model Training**

# %%
#Indexing date
df = df.set_index('date')

#Handling categorical data
df = pd.get_dummies(df, drop_first = True)
df.head()
# Out:
#                   Usage_kWh  Lagging_Current_Reactive_Power_kVarh  \
# date
# 01-01-2018 00:15       3.17                                  2.95
# 01-01-2018 00:30       4.00                                  4.46
# 01-01-2018 00:45       3.24                                  3.28
# 01-01-2018 01:00       3.31                                  3.56
# 01-01-2018 01:15       3.82                                  4.50
#
#                   Leading_Current_Reactive_Power_kVarh  CO2  \
# date
# 01-01-2018 00:15                                   0.0  0.0
# 01-01-2018 00:30                                   0.0  0.0
# 01-01-2018 00:45                                   0.0  0.0
# 01-01-2018 01:00                                   0.0  0.0
# 01-01-2018 01:15                                   0.0  0.0
#
#                   Lagging_Current_Power_Factor  Leading_Current_Power_Factor  \
# date
# 01-01-2018 00:15                         73.21                         100.0
# 01-01-2018 00:30                         66.77                         100.0
# 01-01-2018 00:45                         70.28                         100.0
# 01-01-2018 01:00                         68.09                         100.0
# 01-01-2018 01:15                         64.72                         100.0
#
#                      NSM  WeekStatus_Weekday  WeekStatus_Weekend  \
# date
# 01-01-2018 00:15   900.0                True               False
# 01-01-2018 00:30  1800.0                True               False
# 01-01-2018 00:45  2700.0                True               False
# 01-01-2018 01:00  3600.0                True               False
# 01-01-2018 01:15  4500.0                True               False
#
#                   Load_Type_Encoded  Load_Type_Maximum_Load  \
# date
# 01-01-2018 00:15                  0                   False
# 01-01-2018 00:30                  0                   False
# 01-01-2018 00:45                  0                   False
# 01-01-2018 01:00                  0                   False
# 01-01-2018 01:15                  0                   False
#
#                   Load_Type_Medium_Load  Power_Factor_Bin_5  \
# date
# 01-01-2018 00:15                  False               False
# 01-01-2018 00:30                  False               False
# 01-01-2018 00:45                  False               False
# 01-01-2018 01:00                  False               False
# 01-01-2018 01:15                  False               False
#
#                   Power_Factor_Bin_2  Power_Factor_Bin_10
# date
# 01-01-2018 00:15               False                 True
# 01-01-2018 00:30               False                 True
# 01-01-2018 00:45               False                 True
# 01-01-2018 01:00               False                 True
# 01-01-2018 01:15               False                 True

# %%
#Splitting data set
from sklearn.model_selection import train_test_split
X = df.drop('Usage_kWh', axis = 1)
y = df['Usage_kWh']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

# %%
X_train
# Out:
#                   Lagging_Current_Reactive_Power_kVarh  \
# date
# 11-03-2018 00:15                                  2.63
# 29-01-2018 04:45                                  3.92
# 07-05-2018 14:00                                 36.83
# 11-01-2018 19:00                                 36.94
# 29-01-2018 19:15                                 39.17
# ...                                                ...
# 10-01-2018 10:30                                 32.65
# 24-02-2018 02:15                                  4.72
# 07-05-2018 19:15                                 31.10
# 03-01-2018 11:00                                 31.64
# 20-05-2018 01:30                                  5.22
#
#                   Leading_Current_Reactive_Power_kVarh   CO2  \
# date
# 11-03-2018 00:15                                  0.00  0.00
# 29-01-2018 04:45                                  0.00  0.00
# 07-05-2018 14:00                                  0.00  0.05
# 11-01-2018 19:00                                  0.00  0.05
# 29-01-2018 19:15                                  0.00  0.04
# ...                                                ...   ...
# 10-01-2018 10:30                                  0.00  0.05
# 24-02-2018 02:15                                  0.00  0.00
# 07-05-2018 19:15                                  0.00  0.05
# 03-01-2018 11:00                                  0.04  0.03
# 20-05-2018 01:30                                  0.00  0.00
#
#                   Lagging_Current_Power_Factor  Leading_Current_Power_Factor  \
# date
# 11-03-2018 00:15                         75.84                         100.0
# 29-01-2018 04:45                         72.61                         100.0
# 07-05-2018 14:00                         93.70                         100.0
# 11-01-2018 19:00                         94.55                         100.0
# 29-01-2018 19:15                         91.66                         100.0
# ...                                        ...                           ...
# 10-01-2018 10:30                         95.55                         100.0
# 24-02-2018 02:15                         78.49                         100.0
# 07-05-2018 19:15                         95.96                         100.0
# 03-01-2018 11:00                         92.06                         100.0
# 20-05-2018 01:30                         51.06                         100.0
#
#                       NSM  WeekStatus_Weekday  WeekStatus_Weekend  \
# date
# 11-03-2018 00:15    900.0               False                True
# 29-01-2018 04:45  17100.0                True               False
# 07-05-2018 14:00  50400.0                True               False
# 11-01-2018 19:00  68400.0                True               False
# 29-01-2018 19:15  69300.0                True               False
# ...                   ...                 ...                 ...
# 10-01-2018 10:30  37800.0                True               False
# 24-02-2018 02:15   8100.0               False                True
# 07-05-2018 19:15  69300.0                True               False
# 03-01-2018 11:00  39600.0                True               False
# 20-05-2018 01:30   5400.0               False                True
#
#                   Load_Type_Encoded  Load_Type_Maximum_Load  \
# date
# 11-03-2018 00:15                  0                   False
# 29-01-2018 04:45                  0                   False
# 07-05-2018 14:00                  1                    True
# 11-01-2018 19:00                  1                    True
# 29-01-2018 19:15                  1                    True
# ...                             ...                     ...
# 10-01-2018 10:30                  1                    True
# 24-02-2018 02:15                  0                   False
# 07-05-2018 19:15                  2                   False
# 03-01-2018 11:00                  1                    True
# 20-05-2018 01:30                  0                   False
#
#                   Load_Type_Medium_Load  Power_Factor_Bin_5  \
# date
# 11-03-2018 00:15                  False               False
# 29-01-2018 04:45                  False               False
# 07-05-2018 14:00                  False               False
# 11-01-2018 19:00                  False               False
# 29-01-2018 19:15                  False               False
# ...                                 ...                 ...
# 10-01-2018 10:30                  False               False
# 24-02-2018 02:15                  False               False
# 07-05-2018 19:15                   True               False
# 03-01-2018 11:00                  False               False
# 20-05-2018 01:30                  False               False
#
#                   Power_Factor_Bin_2  Power_Factor_Bin_10
# date
# 11-03-2018 00:15               False                 True
# 29-01-2018 04:45               False                 True
# 07-05-2018 14:00               False                 True
# 11-01-2018 19:00               False                 True
# 29-01-2018 19:15               False                 True
# ...                              ...                  ...
# 10-01-2018 10:30               False                 True
# 24-02-2018 02:15               False                 True
# 07-05-2018 19:15               False                 True
# 03-01-2018 11:00               False                 True
# 20-05-2018 01:30               False                 True
#
# [9392 rows x 14 columns]

# %%
# Linear Regression Model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Initialize and fit the Linear Regression model
lr = LinearRegression()
lr.fit(X_train, y_train)

# Predict on the test set
y_pred = lr.predict(X_test)

# Calculate R²
r2 = r2_score(y_test, y_pred)

# Calculate Adjusted R²
n = X_test.shape[0]  # Number of samples
p = X_test.shape[1]  # Number of features
adjusted_r2 = 1 - ((1 - r2) * (n - 1) / (n - p - 1))

# Print the results
print(f"R² Score for Linear Regression: {r2:.4f}")
print(f"Adjusted R² Score for Linear Regression: {adjusted_r2:.4f}")
# Out:
# R² Score for Linear Regression: 0.9794
# Adjusted R² Score for Linear Regression: 0.9793

# %%
import xgboost as xgb
from sklearn.metrics import r2_score

#XGBoost regressor
xg_reg = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100, learning_rate=0.1, max_depth=5)

# Train the model
xg_reg.fit(X_train, y_train)

# Predict on the test set
y_pred = xg_reg.predict(X_test)

# Calculate R²
r2 = r2_score(y_test, y_pred)

# Calculate Adjusted R²
n = X_test.shape[0]  # Number of samples
p = X_test.shape[1]  # Number of features
adjusted_r2 = 1 - ((1 - r2) * (n - 1) / (n - p - 1))

# Display the results
print(f"R²: {r2:.4f}")
print(f"Adjusted R²: {adjusted_r2:.4f}")
# Out:
# R²: 0.9956
# Adjusted R²: 0.9956
